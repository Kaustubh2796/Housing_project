# %%
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [raw]
# data.info()

# %%
plt.figure(figsize=(20,25), facecolor='yellow')
ax=plt.subplot(3,3,3)
sns.distplot(data['LotFrontage'])
plt.xlabel('LotFrontage',fontsize=20)
plt.show()

# %%
# Out:
# 0

# %%
data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL     70.98847     4928   Pave   NaN      IR1
# 1     889          20       RL     95.00000    15865   Pave   NaN      IR1
# 2     793          60       RL     92.00000     9920   Pave   NaN      IR1
# 3     110          20       RL    105.00000    11751   Pave   NaN      IR1
# 4     422          20       RL     70.98847    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL     70.98847     9819   Pave   NaN      IR1
# 1164  554          20       RL     67.00000     8777   Pave   NaN      Reg
# 1165  196         160       RL     24.00000     2280   Pave   NaN      Reg
# 1166   31          70  C (all)     50.00000     8500   Pave  Pave      Reg
# 1167  617          60       RL     70.98847     7861   Pave   NaN      IR1
#
# ...

# %%
plt.figure(figsize=(20,25), facecolor='yellow')
ax=plt.subplot(3,3,3)
sns.distplot(data['LotFrontage'])
plt.xlabel('LotFrontage',fontsize=20)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2657: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#import statsmodel.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

data=pd.read_csv('Housingtrain.csv')
data.head()


mean_value=data['LotFrontage'].mean()
data['LotFrontage'].fillna(value=mean_value, inplace=True)
data['LotFrontage'].isnull().sum()

from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()#instantiate

df=lab_enc.fit_transform(data['MSZoning'])
data['MSZoning']=df
data

df=lab_enc.fit_transform(data['Street'])
data['Street']=df
data

df=lab_enc.fit_transform(data['Alley'])
data['Alley']=df
data

mean_value1=data['Alley'].mode()
data['Alley'].fillna(value=mean_value1, inplace=True)
data['Alley'].isnull().sum()

df=lab_enc.fit_transform(data['LotShape'])
data['LotShape']=df
data

df=lab_enc.fit_transform(data['LandContour'])
data['LandContour']=df
data

df=lab_enc.fit_transform(data['Utilities'])
data['Utilities']=df
data

df=lab_enc.fit_transform(data['LotConfig'])
data['LotConfig']=df
data

df=lab_enc.fit_transform(data['LandSlope'])
data['LandSlope']=df
data

df=lab_enc.fit_transform(data['Neighborhood'])
data['Neighborhood']=df
data

df=lab_enc.fit_transform(data['Condition1'])
data['Condition1']=df
data

df=lab_enc.fit_transform(data['Condition2'])
data['Condition2']=df
data

df=lab_enc.fit_transform(data['BldgType'])
data['BldgType']=df
data

df=lab_enc.fit_transform(data['HouseStyle'])
data['HouseStyle']=df
data

df=lab_enc.fit_transform(data['RoofStyle'])
data['RoofStyle']=df
data

df=lab_enc.fit_transform(data['RoofMatl'])
data['RoofMatl']=df
data

df=lab_enc.fit_transform(data['Exterior1st'])
data['Exterior1st']=df
data

df=lab_enc.fit_transform(data['Exterior2nd'])
data['Exterior2nd']=df
data

df=lab_enc.fit_transform(data['MasVnrType'])
data['MasVnrType']=df
data

mean_value1=data['MasVnrType'].mode()
data['MasVnrType'].fillna(value=mean_value1, inplace=True)
data['MasVnrType'].isnull().sum()

df=lab_enc.fit_transform(data['MasVnrArea'])
data['MasVnrArea']=df
data

mean_value1=data['MasVnrArea'].mean()
data['MasVnrArea'].fillna(value=mean_value1, inplace=True)
data['MasVnrArea'].isnull().sum()

df=lab_enc.fit_transform(data['ExterQual'])
data['ExterQual']=df
data

df=lab_enc.fit_transform(data['ExterCond'])
data['ExterCond']=df
data

df=lab_enc.fit_transform(data['Foundation'])
data['Foundation']=df
data

df=lab_enc.fit_transform(data['BsmtQual'])
data['BsmtQual']=df
data

mean_value1=data['BsmtQual'].mode()
data['BsmtQual'].fillna(value=mean_value1, inplace=True)
data['BsmtQual'].isnull().sum()

df=lab_enc.fit_transform(data['BsmtCond'])
data['BsmtCond']=df
data

mean_value1=data['BsmtCond'].mode()
data['BsmtCond'].fillna(value=mean_value1, inplace=True)
data['BsmtCond'].isnull().sum()

df=lab_enc.fit_transform(data['BsmtExposure'])
data['BsmtExposure']=df
data

mean_value1=data['BsmtExposure'].mode()
data['BsmtExposure'].fillna(value=mean_value1, inplace=True)
data['BsmtExposure'].isnull().sum()

df=lab_enc.fit_transform(data['BsmtFinType1'])
data['BsmtFinType1']=df
data

mean_value1=data['BsmtFinType1'].mode()
data['BsmtFinType1'].fillna(value=mean_value1, inplace=True)
data['BsmtFinType1'].isnull().sum()

df=lab_enc.fit_transform(data['BsmtFinType2'])
data['BsmtFinType2']=df
data

mean_value1=data['BsmtFinType2'].mode()
data['BsmtFinType2'].fillna(value=mean_value1, inplace=True)
data['BsmtFinType2'].isnull().sum()

df=lab_enc.fit_transform(data['Heating'])
data['Heating']=df
data

df=lab_enc.fit_transform(data['HeatingQC'])
data['HeatingQC']=df
data

df=lab_enc.fit_transform(data['CentralAir'])
data['CentralAir']=df
data

df=lab_enc.fit_transform(data['Electrical'])
data['Electrical']=df
data

df=lab_enc.fit_transform(data['KitchenQual'])
data['KitchenQual']=df
data

df=lab_enc.fit_transform(data['Functional'])
data['Functional']=df
data

df=lab_enc.fit_transform(data['FireplaceQu'])
data['FireplaceQu']=df
data

mean_value1=data['FireplaceQu'].mean()
data['FireplaceQu'].fillna(value=mean_value1, inplace=True)
data['FireplaceQu'].isnull().sum()

df=lab_enc.fit_transform(data['GarageType'])
data['GarageType']=df
data

mean_value1=data['GarageYrBlt'].mode()
data['GarageYrBlt'].fillna(value=mean_value1, inplace=True)
data['GarageYrBlt'].isnull().sum()

df=lab_enc.fit_transform(data['GarageFinish'])
data['GarageFinish']=df
data

mean_value1=data['GarageFinish'].mode()
data['GarageFinish'].fillna(value=mean_value1, inplace=True)
data['GarageFinish'].isnull().sum()

df=lab_enc.fit_transform(data['GarageQual'])
data['GarageQual']=df
data

mean_value1=data['GarageQual'].mode()
data['GarageQual'].fillna(value=mean_value1, inplace=True)
data['GarageQual'].isnull().sum()

df=lab_enc.fit_transform(data['GarageCond'])
data['GarageCond']=df
data

mean_value1=data['GarageCond'].mode()
data['GarageCond'].fillna(value=mean_value1, inplace=True)
data['GarageCond'].isnull().sum()

df=lab_enc.fit_transform(data['PavedDrive'])
data['PavedDrive']=df
data

df=lab_enc.fit_transform(data['PoolQC'])
data['PoolQC']=df
data

mean_value1=data['PoolQC'].mode()
data['PoolQC'].fillna(value=mean_value1, inplace=True)
data['PoolQC'].isnull().sum()

df=lab_enc.fit_transform(data['Fence'])
data['Fence']=df
data

mean_value1=data['Fence'].mode()
data['Fence'].fillna(value=mean_value1, inplace=True)
data['Fence'].isnull().sum()

df=lab_enc.fit_transform(data['MiscFeature'])
data['MiscFeature']=df
data

mean_value1=data['MiscFeature'].mode()
data['MiscFeature'].fillna(value=mean_value1, inplace=True)
data['MiscFeature'].isnull().sum()

df=lab_enc.fit_transform(data['SaleType'])
data['SaleType']=df
data

df=lab_enc.fit_transform(data['SaleCondition'])
data['SaleCondition']=df
data

k=data.drop('GarageYrBlt',axis=1)
l=k.drop('Id',axis=1)

data.drop('Id',axis=1,inplace=True)

data.drop_duplicates(inplace=True)

X=l.drop('SalePrice',axis=1)
y=data['SalePrice']

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 0 to 1167
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   int32
#  2   LotFrontage    1168 non-null   float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   int32
#  5   Alley          1168 non-null   int32
#  6   LotShape       1168 non-null   int32
#  7   LandContour    1168 non-null   int32
#  8   Utilities      1168 non-null   int32
#  9   LotConfig      1168 non-null   int32
#  10  LandSlope      1168 non-null   int32
#  11  Neighborhood   1168 non-null   int32
#  12  Condition1     1168 non-null   int32
#  13  Condition2     1168 non-null   int32
#  14  BldgType       1168 non-null   int32
#  15  HouseStyle     1168 non-null   int32
#  16  OverallQual    1168 non-null   int64
#  17  OverallCond    1168 non-null   int64
# ...

# %%
mean_value1=data['GarageYrBlt'].mode()
data['GarageYrBlt'].fillna(value=mean_value1, inplace=True)
data['GarageYrBlt'].isnull().sum()
# Out:
# 64

# %%
plt.figure(figsize=(20,25), facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=90:
        ax=plt.subplot(30,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        print(column)
    plotnumber+=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
data
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0            120         3     70.98847     4928       1      2         0
# 1             20         3     95.00000    15865       1      2         0
# 2             60         3     92.00000     9920       1      2         0
# 3             20         3    105.00000    11751       1      2         0
# 4             20         3     70.98847    16635       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1163          20         3     70.98847     9819       1      2         0
# 1164          20         3     67.00000     8777       1      2         3
# 1165         160         3     24.00000     2280       1      2         3
# 1166          70         0     50.00000     8500       1      1         3
# 1167          60         3     70.98847     7861       1      2         0
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
#Lets visualize the dataset and analyze the data
plt.figure(figsize=(50,150), facecolor='yellow')
plotnumber = 1

for column in data:
    if plotnumber<=88:
        ax=plt.subplot(22,4,plotnumber)#Print in 2 rows and 4 columns plotnumer = position
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Price',fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GarageYrBlt'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
scaler=StandardScaler()#instantiate inot object
X_scaled=scaler.fit_transform(X)

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.25,random_state=49)   #feature then label and random state is kept for just checking the randomness
y_train.head()
# Out:
# 675     94750
# 523    350000
# 489    132250
# 629    271000
# 192    295000
# Name: SalePrice, dtype: int64

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
data.tail(2)
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 1166          70         0     50.00000     8500       1      1         3
# 1167          60         3     70.98847     7861       1      2         0
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 1166            3          0          4  ...         0       3      2
# 1167            3          0          4  ...         0       3      4
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 1166            4        0       7    2008         8              4      40000
# 1167            4        0       6    2006         8              4     183200
#
# [2 rows x 80 columns]
